# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv("car-price-prediction.csv")
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.info()
data2=data.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
print(data.isnull().sum())
data=data.loc[data.mileage.notnull()]
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           1
# seats            0
# dtype: int64

# %%
data["name"].nunique()
# Out:
# 1983

# %%
print(data["mileage"].str.contains("kmpl").value_counts())
data["mileage"].str.contains("km/kg").value_counts()
# Out:
# mileage
# True     7819
# False      88
# Name: count, dtype: int64
# mileage
# False    7819
# True       88
# Name: count, dtype: int64

# %%
data[data["mileage"].str.contains("km/kg")].fuel.unique()
# Out:
# array(['LPG', 'CNG'], dtype=object)

# %%
datakmpg=data[data["mileage"].str.contains("km/kg")].copy()

# %%
datakmpg
# Out:
#                                         name  year  selling_price  km_driven  \
# 6               Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 35          Maruti Alto 800 CNG LXI Optional  2019         330000      10000
# 90               Maruti Wagon R LXI LPG BSIV  2010         225000      44000
# 203                   Maruti Wagon R LXI CNG  2016         360000      50000
# 402              Maruti Eeco CNG 5 Seater AC  2020         409999      35000
# ...                                      ...   ...            ...        ...
# 7308             Maruti Alto Green LXi (CNG)  2010         155000      70000
# 7543        Maruti Alto 800 CNG LXI Optional  2019         330000      10000
# 7642              Chevrolet Spark 1.0 LT LPG  2012         300000      70000
# 7733        Maruti Eeco CNG 5 Seater AC BSIV  2015         380000      20000
# 7913  Maruti Eeco 5 STR With AC Plus HTR CNG  2011         209000          1
#
# ...

# %%
datakmpg['mileage']=datakmpg["mileage"].str.replace("km/kg","")

# %%
## kmpl=dist/vol dist/(mass/density) density*(dist/mass)

# %%
dataaaa=datakmpg.copy()

# %%
datakmpg.loc[datakmpg.fuel=='LPG',"mileage"].astype(float).multiply(1.96)
# Out:
# 6       33.908
# 90      51.352
# 870     51.352
# 1511    51.352
# 1658    33.908
# 1907    26.362
# 2108    33.908
# 2166    33.908
# 2484    26.362
# 2518    51.352
# 2579    51.352
# 2588    51.352
# 3010    26.362
# 3042    37.632
# 3050    51.352
# 3216    34.888
# 3466    21.364
# 3492    51.352
# 3751    26.362
# 3796    33.908
# 3823    37.632
# 4045    41.356
# 4545    37.632
# 5436    32.536
# 5437    31.360
# 5578    33.908
# 5768    37.632
# 6007    21.364
# 6253    37.240
# 6338    51.352
# 6856    26.362
# 7101    25.872
# 7112    28.224
# 7245    26.362
# 7642    25.872
# Name: mileage, dtype: float64

# %%
datakmpg.loc[datakmpg.fuel=='LPG',"mileage"]=datakmpg.loc[datakmpg.fuel=='LPG',"mileage"].astype(float).multiply(1.96)

# %%
datakmpg
# Out:
#                                         name  year  selling_price  km_driven  \
# 6               Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 35          Maruti Alto 800 CNG LXI Optional  2019         330000      10000
# 90               Maruti Wagon R LXI LPG BSIV  2010         225000      44000
# 203                   Maruti Wagon R LXI CNG  2016         360000      50000
# 402              Maruti Eeco CNG 5 Seater AC  2020         409999      35000
# ...                                      ...   ...            ...        ...
# 7308             Maruti Alto Green LXi (CNG)  2010         155000      70000
# 7543        Maruti Alto 800 CNG LXI Optional  2019         330000      10000
# 7642              Chevrolet Spark 1.0 LT LPG  2012         300000      70000
# 7733        Maruti Eeco CNG 5 Seater AC BSIV  2015         380000      20000
# 7913  Maruti Eeco 5 STR With AC Plus HTR CNG  2011         209000          1
#
# ...

# %%
data["fuel"].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
encode=LabelEncoder()
label=encode.fit_transform(data.fuel)
data["encoded_fuel"]=label
# Out:
# C:\Users\SAHIL MOHRIL\AppData\Local\Temp\ipykernel_32116\2035816003.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["encoded_fuel"]=label

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['transmission'].unique()
#data=data.loc[:,'transmission_code']
label=encode.fit_transform(data.transmission)
data=data.copy()
data['transmission_encode']=label
data[data['transmission']=='Automatic']
# Out:
#                                      name  year  selling_price  km_driven  \
# 41     Jeep Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 44              Maruti Swift Dzire VXi AT  2018         675000      23300
# 49             Mercedes-Benz B Class B180  2014        1450000      27800
# 55    Toyota Innova Crysta 2.8 ZX AT BSIV  2016        1650000     127700
# 57             Audi A6 2.0 TDI Technology  2013        1750000      33900
# ...                                   ...   ...            ...        ...
# 8058              Audi A3 40 TFSI Premium  2017        1689999       8000
# 8063       Hyundai Creta 1.6 SX Automatic  2016         890000      40000
# 8081                    Honda City ZXi AT  2005         110000     100000
# 8086          Maruti Celerio ZXI AMT BSIV  2018         470000      30000
# 8108             Kia Seltos HTX Plus AT D  2019        1575000      20000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %%
data['owner'].unique()
label=encode.fit_transform(data.owner)
data=data.copy()
data['owner_encode']=label
data['max_power'].str.contains("bhp").size-data['max_power'].size
# Out:
# 0

# %%
data2=data.copy()
data2['max_power']=data['max_power'].str.replace("bhp","")
data2['engine']=data['engine'].str.replace("CC","")
data2
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data2['engine']=data2['engine'].astype(int)
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7907 entries, 0 to 8127
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 7907 non-null   object
#  1   year                 7907 non-null   int64
#  2   selling_price        7907 non-null   int64
#  3   km_driven            7907 non-null   int64
#  4   fuel                 7907 non-null   object
#  5   seller_type          7907 non-null   object
#  6   transmission         7907 non-null   object
#  7   owner                7907 non-null   object
#  8   mileage              7907 non-null   object
#  9   engine               7907 non-null   int32
#  10  max_power            7907 non-null   object
#  11  torque               7906 non-null   object
#  12  seats                7907 non-null   float64
#  13  encoded_fuel         7907 non-null   int32
#  14  transmission_encode  7907 non-null   int32
# ...

# %%
data2[data2['max_power'].str.contains(" ")]
data2['max_power'].str.replace(" ",'#').str.rstrip(" ")
# Out:
# 0           74#
# 1       103.52#
# 2           78#
# 3           90#
# 4         88.2#
#          ...
# 8123     82.85#
# 8124       110#
# 8125      73.9#
# 8126        70#
# 8127        70#
# Name: max_power, Length: 7907, dtype: object
